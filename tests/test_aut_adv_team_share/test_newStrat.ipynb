# %%
import sys

from autograph.play.maze_nn_aut_adv_team_share import init_game
from autograph.lib.util.test_helper_team import doenvsteps, get_and_plot_policies

#config_file = 'autograph/play/config/LiorBrett/seeBothInfs.json'
# use a limited quick MCTS search
# config_file = '../../autograph/play/config/guardInf/newActions/partial_500_Auts_10by10.json'
config_file = '../../autograph/play/config/guardInf/newActions/full_500_Auts_10by10.json'
# Checkpoint path
checkpoint_base_path = '../../checkpoints/newActionsCass/may14/%s'


# If you don't want to use a checkpoint, use this
#checkpoint_base_path = ''
run_name = 'full_500_Auts_10by10_cas'
postfix = ''

envs, get_pi_cnn, do_mcts_batch, get_tree_and_play_policies = init_game(config_file, checkpoint_base_path,run_name,postfix, "cpu")

# %%
actionlist = [[0,0],
              [],
              [1,1],
              []]
stepnum, done, lastplayer, lastrew, lastautstate, finishedrun = doenvsteps(envs, actionlist, do_mcts_batch=do_mcts_batch)
assert(finishedrun)

print("")
envs[0].render()
get_and_plot_policies(envs, do_mcts_batch=do_mcts_batch, get_pi_cnn=get_pi_cnn, get_tree_and_play_policies=get_tree_and_play_policies)
# Out:
# +---+---+---+---+---+---+---+---+---+---+
# |1>      3>                    B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |  S                           B       S|
# +   +   +   +   +   +   +   +   +   +   +
# |  B   B   B   B   B   B   B   B   B   B|
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |                      k             0^ |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |        2>    k                        |
# +---+---+---+---+---+---+---+---+---+---+
# 0 ^ at  (9, 7)  has {'keycard': 0, 'box': 2, 'weapon': 0}
# 1 > at  (0, 0)  has {}
# 2 > at  (2, 9)  has {'keycard': 0, 'box': 2, 'weapon': 0}
# 3 > at  (2, 0)  has {}

# %%
actionlist = [[3, 1, 1,1,1,0],
              [],
              [],
              []]
stepnum, done, lastplayer, lastrew, lastautstate, finishedrun = doenvsteps(envs, actionlist, do_mcts_batch=do_mcts_batch)
assert(finishedrun)

print("")
envs[0].render()
get_and_plot_policies(envs, do_mcts_batch=do_mcts_batch, get_pi_cnn=get_pi_cnn, get_tree_and_play_policies=get_tree_and_play_policies)
# Out:
# +---+---+---+---+---+---+---+---+---+---+
# |1>      3>                    B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |  S                           B       S|
# +   +   +   +   +   +   +   +   +   +   +
# |  B   B   B   B   B   B   B   B   B   B|
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |                                    0^ |
# +   +   +   +   +   +   +   +   +   +   +
# |                      k                |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |        2>    k                        |
# +---+---+---+---+---+---+---+---+---+---+
# 0 ^ at  (9, 6)  has {'keycard': 0, 'box': 2, 'weapon': 0}
# 1 > at  (0, 0)  has {}
# 2 > at  (2, 9)  has {'keycard': 0, 'box': 2, 'weapon': 0}
# 3 > at  (2, 0)  has {}

# %%
actionlist = [[0],
              [],
              [],
              []]
stepnum, done, lastplayer, lastrew, lastautstate, finishedrun = doenvsteps(envs, actionlist, do_mcts_batch=do_mcts_batch)
assert(finishedrun)

print("")
envs[0].render()
get_and_plot_policies(envs, do_mcts_batch=do_mcts_batch, get_pi_cnn=get_pi_cnn, get_tree_and_play_policies=get_tree_and_play_policies)
# Out:
# +---+---+---+---+---+---+---+---+---+---+
# |1>      3>                    B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |  S                           B       S|
# +   +   +   +   +   +   +   +   +   +   +
# |  B   B   B   B   B   B   B   B   B   B|
# +   +   +   +   +   +   +   +   +   +   +
# |                                    0^ |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |                      k                |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |        2>    k                        |
# +---+---+---+---+---+---+---+---+---+---+
# 0 ^ at  (9, 5)  has {'keycard': 0, 'box': 2, 'weapon': 0}
# 1 > at  (0, 0)  has {}
# 2 > at  (2, 9)  has {'keycard': 0, 'box': 2, 'weapon': 0}
# 3 > at  (2, 0)  has {}

# %%
actionlist = [[],
              [],
              [1],
              []]
stepnum, done, lastplayer, lastrew, lastautstate, finishedrun = doenvsteps(envs, actionlist, do_mcts_batch=do_mcts_batch)
assert(finishedrun)

print("")
envs[0].render()
get_and_plot_policies(envs, do_mcts_batch=do_mcts_batch, get_pi_cnn=get_pi_cnn, get_tree_and_play_policies=get_tree_and_play_policies)
# Out:
# +---+---+---+---+---+---+---+---+---+---+
# |1>      3>                    B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |  S                           B       S|
# +   +   +   +   +   +   +   +   +   +   +
# |  B   B   B   B   B   B   B   B   B   B|
# +   +   +   +   +   +   +   +   +   +   +
# |                                    0^ |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |                      k                |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |            2>                         |
# +---+---+---+---+---+---+---+---+---+---+
# 0 ^ at  (9, 5)  has {'keycard': 0, 'box': 2, 'weapon': 0}
# 1 > at  (0, 0)  has {}
# 2 > at  (3, 9)  has {'keycard': 1, 'box': 2, 'weapon': 0}
# 3 > at  (2, 0)  has {}

# %%
actionlist = [[0],
              [],
              [],
              []]
stepnum, done, lastplayer, lastrew, lastautstate, finishedrun = doenvsteps(envs, actionlist, do_mcts_batch=do_mcts_batch)
assert(finishedrun)

print("")
envs[0].render()
get_and_plot_policies(envs, do_mcts_batch=do_mcts_batch, get_pi_cnn=get_pi_cnn, get_tree_and_play_policies=get_tree_and_play_policies)
# Out:
# +---+---+---+---+---+---+---+---+---+---+
# |1>      3>                    B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |                              B        |
# +   +   +   +   +   +   +   +   +   +   +
# |  S                           B       S|
# +   +   +   +   +   +   +   +   +   +   +
# |  B   B   B   B   B   B   B   B   B 0^ |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |                      k                |
# +   +   +   +   +   +   +   +   +   +   +
# |                                       |
# +   +   +   +   +   +   +   +   +   +   +
# |            2>                         |
# +---+---+---+---+---+---+---+---+---+---+
# 0 ^ at  (9, 4)  has {'keycard': 0, 'box': 3, 'weapon': 0}
# 1 > at  (0, 0)  has {}
# 2 > at  (3, 9)  has {'keycard': 1, 'box': 2, 'weapon': 0}
# 3 > at  (2, 0)  has {}
